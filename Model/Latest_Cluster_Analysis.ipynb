# %%
import pandas as pd, numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import seaborn as sns
import pickle

sns.set_palette("deep", desat=0.6)
sns.set_context(rc={"figure.figsize": (8,4)})
import json
from urllib.request import urlopen
import requests
from shapely.geometry import shape, Point

from sklearn.cluster import DBSCAN
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
from datetime import datetime as dt
import time
import folium
from IPython.core.display import HTML

# %% [markdown]
# # Utility Functions

# %%
def getcoords(dframe):
    dfgeo1 = dframe.dropna(subset = ['LATITUDE','LONGITUDE'])
    coords = dfgeo1.as_matrix(columns=['LATITUDE','LONGITUDE'])
    return coords

# %%
def applyDBSCAN(coordinates, epsilon, min_samples):
    start_time = time.time()
    db = DBSCAN(eps=epsilon, min_samples = min_samples, algorithm='ball_tree', metric='haversine').fit(np.radians(coordinates))
    cluster_labels = db.labels_
    # get the number of clusters
    num_clusters = len(set(cluster_labels))
    print(num_clusters)
    clusters = pd.Series([coordinates[cluster_labels==n] for n in range(num_clusters)])
    message = 'Clustered {:,} points down to {:,} clusters, for {:.1f}% compression in {:,.2f} seconds'
    print(message.format(len(coordinates), num_clusters, 100*(1 - float(num_clusters) / len(coordinates)), time.time()-start_time))
    return clusters

# %%
def get_centermost_point(clusters):
    centroid = (MultiPoint(clusters).centroid.x, MultiPoint(clusters).centroid.y)
    centermost_point = min(clusters, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)

# %%
#Find the point in each cluster that is closest to its centroid
def gethotspots(clusters, df, min_sample):
    centermost_points = []
    for cluster in clusters.iteritems():
        if len(cluster[1]) >= min_sample:
            centermost_points.append(get_centermost_point(cluster[1]))
    lats, lons = zip(*centermost_points)
    rep_points = pd.DataFrame({'lon':lons, 'lat':lats})
    # pull row from original data set where lat/lon match the lat/lon of each row of representative points
    # that way we get the full details from the original dataframe
    rs = rep_points.apply(lambda row: df[(df['LATITUDE']==row['lat']) & 
                                             (df['LONGITUDE']==row['lon'])].iloc[0], axis=1)
    return rs

# %%
def plotHotSpots(orgdf, rset):
    # plot the final reduced set of coordinate points vs the original full set
    fig, ax = plt.subplots(figsize=[17.5, 17])
    df_scatter1 = ax.scatter(orgdf['LONGITUDE'], orgdf['LATITUDE'], c='k', alpha=0.9, s=3)
    rs_scatter1 = ax.scatter(rset['LONGITUDE'], rset['LATITUDE'], c='#FF8C00', edgecolor='None', alpha=0.7, s=120)
    ax.set_title('Full data set vs DBSCAN reduced set')
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.set_xlim(-74.06, -73.77)
    ax.set_ylim(40.61, 40.91)
    ax.legend([df_scatter1, rs_scatter1], ['Full set', 'Reduced set'], loc='upper right')
    plt.show()

# %%
def buildFoliumMap(rs):
    NY_COORDINATES = (40.61, -74.06)
    # create empty map zoomed in on NYC
    map = folium.Map(location=NY_COORDINATES, zoom_start=11)
    
    for each in rs.iterrows():
        folium.CircleMarker(
            location = [each[1]['LATITUDE'],each[1]['LONGITUDE']],
            radius = 12, popup= str(each[1]['BOROUGH']) + ": " + str(each[1]["ON.STREET.NAME"]) + "(zip:" + str(each[1]["ZIP.CODE"]) + ")",
        fill=True, color='#3186cc', fill_color='#FF8C00', fill_opacity=0.7).add_to(map)
    return map

# %%
def plotHotSpots_Folium(rs):
    display(buildFoliumMap(rs))

# %%
kms_per_radian = 6371.0088

# %%
def prepareHotSpotsForFullData(df_fulldata):
    rs = pd.DataFrame()
    coords = getcoords(df_fulldata)
    for min_sample in range(10, 110, 10):
        for i in range(0, 11, 1):
            if i != 0:
                tmp = i / 10.0
                epsilon = tmp / kms_per_radian
                clusters = applyDBSCAN(coords, epsilon, min_sample)
                hsdata = gethotspots(clusters, df_fulldata, min_sample)
                hsdata['EPSILON'] = tmp
                hsdata['SAMPLES'] = min_sample
                rs = rs.append(hsdata)
    return rs

# %%
#Clean and get right dataframe
def cleandf(df,vz):
    df.drop(df.iloc[:, 0:2], inplace=True, axis=1)
    df['VZ'] = vz
    filter = (df["LATITUDE"].notnull()) & (df["LONGITUDE"].notnull())
    df = df[filter]  
    df['YEAR'], df['MONTH'],df['DAY_OF_WEEK']= df['DATE'].apply(lambda x: x.year), df['DATE'].apply(lambda x: x.month), df['DATE'].apply(lambda x: x.weekday())
    df['NBR_VZ_INITIATIVES'] = df['SLOWZONE'] + df['SPEED_HUMP'] + df['SIGNAL_TIMING'] + df['BIKE_PRIORITY'] + df['ENHANCED_CROSSING'] + df['LEAD_PEDESTRIAN_INTERVAL'] + df['LEFT_TURN_TRAFFIC_CALMING'] + df['NEIGHBORHOOD_SLOW_ZONE'] + df['SAFE_STREETS_FOR_SENIORS'] + df['SIP_INTERSECTIONS']+ df['SAFE_CORRIDORS'] + df['PRIORITY_CORRIDORS'] + df['PRIORITY_INTERSECTIONS'] + df['PRIORITY_ZONES']
    return df

# %%
#df.to_csv('pedestrian-incidents-fulldata.csv', encoding='utf-8', index=False)

# %% [markdown]
# ## Load the pedestrian data before vision zero initiative

# %%
dfped_nvz = pd.read_csv('LatestData/EDA/pedestrian_nvz.csv', parse_dates=[2])

# %%
dfped_nvz = cleandf(dfped_nvz, 0)
dfped_nvz.shape
# Out:
# C:\Users\p_sum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# (24496, 47)

# %%
dfped_nvz.head()
# Out:
#         DATE   TIME    BOROUGH  ZIP.CODE   LATITUDE  LONGITUDE  \
# 1 2014-04-08  11:45   BROOKLYN   11211.0  40.706479 -73.963744
# 2 2014-04-08  12:00  MANHATTAN   10019.0  40.768382 -73.992805
# 3 2014-04-08  12:27  MANHATTAN   10075.0  40.773336 -73.955054
# 4 2014-04-08  12:30   BROOKLYN   11213.0  40.669402 -73.942197
# 5 2014-04-08  13:40  MANHATTAN   10017.0  40.751453 -73.978153
#
#                     LOCATION                    ON.STREET.NAME  \
# 1  (40.7064792, -73.9637444)  BEDFORD AVENUE
# 2   (40.7683816, -73.992805)  11 AVENUE
# 3  (40.7733356, -73.9550538)  EAST 79 STREET
# 4  (40.6694023, -73.9421971)  KINGSTON AVENUE
# 5   (40.751453, -73.9781533)  EAST 41 STREET
#
#                   CROSS.STREET.NAME OFF.STREET.NAME     ...      \
# 1  CLYMER STREET                                NaN     ...
# 2  WEST 54 STREET                               NaN     ...
# 3  2 AVENUE                                     NaN     ...
# 4  EASTERN PARKWAY                              NaN     ...
# 5  PARK AVENUE                                  NaN     ...
#
#    SAFE_STREETS_FOR_SENIORS  SIP_INTERSECTIONS  SAFE_CORRIDORS  \
# 1                         0                  0               0
# 2                         0                  0               0
# 3                         1                  0               1
# 4                         0                  0               1
# 5                         0                  0               1
#
#    PRIORITY_CORRIDORS  PRIORITY_INTERSECTIONS  PRIORITY_ZONES  VZ  YEAR MONTH  \
# 1                   0                       0               0   0  2014     4
# 2                   0                       0               0   0  2014     4
# 3                   1                       1               1   0  2014     4
# 4                   1                       1               1   0  2014     4
# 5                   0                       0               1   0  2014     4
#
#   DAY_OF_WEEK
# 1           1
# 2           1
# 3           1
# 4           1
# 5           1
#
# [5 rows x 47 columns]

# %% [markdown]
# # Load the pedestrian data after vision zero initiative

# %%
dfped_vz = pd.read_csv('LatestData/EDA/pedestrian_vz.csv', parse_dates=[2])

# %%
dfped_vz = cleandf(dfped_vz, 1)
dfped_vz.shape
# Out:
# C:\Users\p_sum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# (50969, 47)

# %%
dfped_vz.head()
# Out:
#         DATE   TIME   BOROUGH  ZIP.CODE   LATITUDE  LONGITUDE  \
# 0 2018-04-28   0:00       NaN       NaN  40.685290 -73.976204
# 1 2018-04-28  10:30     BRONX   10462.0  40.854122 -73.867714
# 2 2018-04-28  10:30       NaN       NaN  40.707070 -73.817190
# 3 2018-04-28  12:00  BROOKLYN   11203.0  40.656063 -73.939570
# 4 2018-04-28  12:35       NaN       NaN  40.854626 -73.895160
#
#                   LOCATION                    ON.STREET.NAME  \
# 0   (40.68529, -73.976204)  HANSON PLACE
# 1  (40.854122, -73.867714)                               NaN
# 2    (40.70707, -73.81719)  QUEENS BOULEVARD
# 3   (40.656063, -73.93957)  CLARKSON AVENUE
# 4   (40.854626, -73.89516)  PARK AVENUE
#
#   CROSS.STREET.NAME                           OFF.STREET.NAME     ...      \
# 0               NaN                                       NaN     ...
# 1               NaN  2126      WHITE PLAINS ROAD                  ...
# 2               NaN                                       NaN     ...
# 3     ALBANY AVENUE                                       NaN     ...
# 4               NaN                                       NaN     ...
#
#    SAFE_STREETS_FOR_SENIORS  SIP_INTERSECTIONS  SAFE_CORRIDORS  \
# 0                         0                  0               0
# 1                         0                  0               1
# 2                         0                  0               0
# 3                         0                  0               0
# 4                         0                  0               0
#
#    PRIORITY_CORRIDORS  PRIORITY_INTERSECTIONS  PRIORITY_ZONES  VZ  YEAR MONTH  \
# 0                   0                       0               1   1  2018     4
# 1                   1                       0               0   1  2018     4
# 2                   1                       0               1   1  2018     4
# 3                   0                       0               0   1  2018     4
# 4                   0                       0               1   1  2018     4
#
#   DAY_OF_WEEK
# 0           5
# 1           5
# 2           5
# 3           5
# 4           5
#
# [5 rows x 47 columns]

# %% [markdown]
# # Combine both into one pedestrian data file

# %%
dfped_full = dfped_nvz.append(dfped_vz)

# %%
dfped_full.shape
# Out:
# (75465, 47)

# %%
#Write into a csv file
dfped_full.to_csv('pedestrian-incidents-fulldata-latest.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Find HotSpots and Persist

# %%
hotspots = prepareHotSpotsForFullData(dfped_full)
# Out:
# 1372
# Clustered 75,465 points down to 1,372 clusters, for 98.2% compression in 3.06 seconds
# 250
# Clustered 75,465 points down to 250 clusters, for 99.7% compression in 3.21 seconds
# 78
# Clustered 75,465 points down to 78 clusters, for 99.9% compression in 3.85 seconds
# 41
# Clustered 75,465 points down to 41 clusters, for 99.9% compression in 4.81 seconds
# 23
# Clustered 75,465 points down to 23 clusters, for 100.0% compression in 5.20 seconds
# 15
# Clustered 75,465 points down to 15 clusters, for 100.0% compression in 6.09 seconds
# 14
# Clustered 75,465 points down to 14 clusters, for 100.0% compression in 6.50 seconds
# 12
# Clustered 75,465 points down to 12 clusters, for 100.0% compression in 7.55 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 8.26 seconds
# 7
# Clustered 75,465 points down to 7 clusters, for 100.0% compression in 8.84 seconds
# 693
# Clustered 75,465 points down to 693 clusters, for 99.1% compression in 2.75 seconds
# 245
# Clustered 75,465 points down to 245 clusters, for 99.7% compression in 3.35 seconds
# 69
# Clustered 75,465 points down to 69 clusters, for 99.9% compression in 4.23 seconds
# 37
# Clustered 75,465 points down to 37 clusters, for 100.0% compression in 4.59 seconds
# 22
# Clustered 75,465 points down to 22 clusters, for 100.0% compression in 5.23 seconds
# 14
# Clustered 75,465 points down to 14 clusters, for 100.0% compression in 5.82 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 6.74 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 7.29 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 8.28 seconds
# 7
# Clustered 75,465 points down to 7 clusters, for 100.0% compression in 9.13 seconds
# 343
# Clustered 75,465 points down to 343 clusters, for 99.5% compression in 2.55 seconds
# 227
# Clustered 75,465 points down to 227 clusters, for 99.7% compression in 3.15 seconds
# 69
# Clustered 75,465 points down to 69 clusters, for 99.9% compression in 4.02 seconds
# 38
# Clustered 75,465 points down to 38 clusters, for 99.9% compression in 4.49 seconds
# 25
# Clustered 75,465 points down to 25 clusters, for 100.0% compression in 5.29 seconds
# 19
# Clustered 75,465 points down to 19 clusters, for 100.0% compression in 7.28 seconds
# 12
# Clustered 75,465 points down to 12 clusters, for 100.0% compression in 7.28 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 7.72 seconds
# 6
# Clustered 75,465 points down to 6 clusters, for 100.0% compression in 9.61 seconds
# 5
# Clustered 75,465 points down to 5 clusters, for 100.0% compression in 10.82 seconds
# 155
# Clustered 75,465 points down to 155 clusters, for 99.8% compression in 2.74 seconds
# 226
# Clustered 75,465 points down to 226 clusters, for 99.7% compression in 3.28 seconds
# 57
# Clustered 75,465 points down to 57 clusters, for 99.9% compression in 3.99 seconds
# 42
# Clustered 75,465 points down to 42 clusters, for 99.9% compression in 4.65 seconds
# 20
# Clustered 75,465 points down to 20 clusters, for 100.0% compression in 5.27 seconds
# 19
# Clustered 75,465 points down to 19 clusters, for 100.0% compression in 6.47 seconds
# 16
# Clustered 75,465 points down to 16 clusters, for 100.0% compression in 6.90 seconds
# 11
# Clustered 75,465 points down to 11 clusters, for 100.0% compression in 7.75 seconds
# 7
# Clustered 75,465 points down to 7 clusters, for 100.0% compression in 8.15 seconds
# 5
# Clustered 75,465 points down to 5 clusters, for 100.0% compression in 9.17 seconds
# 86
# Clustered 75,465 points down to 86 clusters, for 99.9% compression in 2.55 seconds
# 179
# Clustered 75,465 points down to 179 clusters, for 99.8% compression in 3.49 seconds
# 52
# Clustered 75,465 points down to 52 clusters, for 99.9% compression in 3.92 seconds
# 38
# Clustered 75,465 points down to 38 clusters, for 99.9% compression in 4.59 seconds
# 25
# Clustered 75,465 points down to 25 clusters, for 100.0% compression in 5.27 seconds
# 14
# Clustered 75,465 points down to 14 clusters, for 100.0% compression in 5.80 seconds
# 14
# Clustered 75,465 points down to 14 clusters, for 100.0% compression in 6.44 seconds
# 13
# Clustered 75,465 points down to 13 clusters, for 100.0% compression in 8.60 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 9.32 seconds
# 6
# Clustered 75,465 points down to 6 clusters, for 100.0% compression in 8.65 seconds
# 46
# Clustered 75,465 points down to 46 clusters, for 99.9% compression in 2.44 seconds
# 146
# Clustered 75,465 points down to 146 clusters, for 99.8% compression in 3.33 seconds
# 58
# Clustered 75,465 points down to 58 clusters, for 99.9% compression in 3.76 seconds
# 23
# Clustered 75,465 points down to 23 clusters, for 100.0% compression in 4.41 seconds
# 26
# Clustered 75,465 points down to 26 clusters, for 100.0% compression in 5.20 seconds
# 15
# Clustered 75,465 points down to 15 clusters, for 100.0% compression in 6.25 seconds
# 12
# Clustered 75,465 points down to 12 clusters, for 100.0% compression in 6.83 seconds
# 12
# Clustered 75,465 points down to 12 clusters, for 100.0% compression in 8.24 seconds
# 10
# Clustered 75,465 points down to 10 clusters, for 100.0% compression in 8.65 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 8.69 seconds
# 24
# Clustered 75,465 points down to 24 clusters, for 100.0% compression in 2.41 seconds
# 101
# Clustered 75,465 points down to 101 clusters, for 99.9% compression in 3.75 seconds
# 49
# Clustered 75,465 points down to 49 clusters, for 99.9% compression in 4.69 seconds
# 26
# Clustered 75,465 points down to 26 clusters, for 100.0% compression in 4.39 seconds
# 23
# Clustered 75,465 points down to 23 clusters, for 100.0% compression in 5.19 seconds
# 20
# Clustered 75,465 points down to 20 clusters, for 100.0% compression in 5.79 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 6.41 seconds
# 12
# Clustered 75,465 points down to 12 clusters, for 100.0% compression in 7.44 seconds
# 10
# Clustered 75,465 points down to 10 clusters, for 100.0% compression in 7.89 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 8.92 seconds
# 10
# Clustered 75,465 points down to 10 clusters, for 100.0% compression in 2.42 seconds
# 65
# Clustered 75,465 points down to 65 clusters, for 99.9% compression in 3.11 seconds
# 69
# Clustered 75,465 points down to 69 clusters, for 99.9% compression in 3.71 seconds
# 25
# Clustered 75,465 points down to 25 clusters, for 100.0% compression in 4.43 seconds
# 16
# Clustered 75,465 points down to 16 clusters, for 100.0% compression in 5.33 seconds
# 15
# Clustered 75,465 points down to 15 clusters, for 100.0% compression in 5.71 seconds
# 12
# Clustered 75,465 points down to 12 clusters, for 100.0% compression in 6.69 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 7.18 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 8.12 seconds
# 6
# Clustered 75,465 points down to 6 clusters, for 100.0% compression in 8.82 seconds
# 7
# Clustered 75,465 points down to 7 clusters, for 100.0% compression in 2.43 seconds
# 53
# Clustered 75,465 points down to 53 clusters, for 99.9% compression in 3.06 seconds
# 67
# Clustered 75,465 points down to 67 clusters, for 99.9% compression in 3.70 seconds
# 25
# Clustered 75,465 points down to 25 clusters, for 100.0% compression in 4.57 seconds
# 14
# Clustered 75,465 points down to 14 clusters, for 100.0% compression in 5.09 seconds
# 19
# Clustered 75,465 points down to 19 clusters, for 100.0% compression in 5.97 seconds
# 13
# Clustered 75,465 points down to 13 clusters, for 100.0% compression in 6.45 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 7.32 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 7.80 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 8.50 seconds
# 3
# Clustered 75,465 points down to 3 clusters, for 100.0% compression in 3.17 seconds
# 40
# Clustered 75,465 points down to 40 clusters, for 99.9% compression in 3.17 seconds
# 62
# Clustered 75,465 points down to 62 clusters, for 99.9% compression in 3.65 seconds
# 38
# Clustered 75,465 points down to 38 clusters, for 99.9% compression in 4.33 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 5.17 seconds
# 14
# Clustered 75,465 points down to 14 clusters, for 100.0% compression in 5.69 seconds
# 14
# Clustered 75,465 points down to 14 clusters, for 100.0% compression in 6.79 seconds
# 9
# Clustered 75,465 points down to 9 clusters, for 100.0% compression in 7.28 seconds
# 8
# Clustered 75,465 points down to 8 clusters, for 100.0% compression in 7.83 seconds
# 6
# Clustered 75,465 points down to 6 clusters, for 100.0% compression in 9.00 seconds

# %%
hotspots.shape
# Out:
# (5452, 49)

# %%
hotspots.to_csv('pedestrian-hotspots-fulldata-latest.csv', encoding='utf-8', index=False)

# %% [markdown]
# # Load 3 vehicle incident data and do the same hotspot findings

# %%
df3veh_nvz = pd.read_csv('LatestData/EDA/threevehicles_nvz.csv', parse_dates=[2])

# %%
df3veh_nvz = cleandf(df3veh_nvz, 0)
# Out:
# C:\Users\p_sum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\p_sum\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df3veh_nvz.head()
# Out:
#         DATE   TIME   BOROUGH  ZIP.CODE   LATITUDE  LONGITUDE  \
# 2 2014-04-08   7:20       NaN       NaN  40.585165 -73.956406
# 3 2014-04-08  10:13     BRONX   10451.0  40.811723 -73.928126
# 5 2014-04-08  10:15  BROOKLYN   11234.0  40.618022 -73.914214
# 6 2014-04-08  12:17       NaN       NaN  40.711541 -73.836232
# 7 2014-04-08  12:20       NaN       NaN  40.806346 -73.933172
#
#                     LOCATION                    ON.STREET.NAME  \
# 2  (40.5851653, -73.9564056)                               NaN
# 3  (40.8117235, -73.9281256)  EAST 138 STREET
# 5  (40.6180217, -73.9142142)  AVENUE T
# 6  (40.7115409, -73.8362317)                               NaN
# 7  (40.8063462, -73.9331715)                               NaN
#
#                   CROSS.STREET.NAME OFF.STREET.NAME        ...          \
# 2                               NaN             NaN        ...
# 3  RIDER AVENUE                                 NaN        ...
# 5  EAST 64 STREET                               NaN        ...
# 6                               NaN             NaN        ...
# 7                               NaN             NaN        ...
#
#    SIP_INTERSECTIONS  SAFE_CORRIDORS  PRIORITY_CORRIDORS  \
# 2                  0               0                   0
# 3                  0               0                   1
# 5                  0               0                   0
# 6                  0               0                   0
# 7                  0               0                   0
#
#    PRIORITY_INTERSECTIONS  PRIORITY_ZONES  VZ  YEAR  MONTH DAY_OF_WEEK  \
# 2                       0               0   0  2014      4           1
# 3                       0               1   0  2014      4           1
# 5                       0               0   0  2014      4           1
# 6                       0               0   0  2014      4           1
# 7                       0               0   0  2014      4           1
#
#   NBR_VZ_INITIATIVES
# 2                  1
# 3                  4
# 5                  0
# 6                  0
# 7                  0
#
# [5 rows x 48 columns]

# %%
df3veh_vz = pd.read_csv('LatestData/EDA/threevehicles_vz.csv', parse_dates=[2])
df3veh_vz = cleandf(df3veh_vz, 1)
df3veh_vz.head()
# Out:
# C:\Users\p_sum\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\p_sum\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         DATE   TIME    BOROUGH  ZIP.CODE   LATITUDE  LONGITUDE  \
# 0 2018-04-28   0:20        NaN       NaN  40.680977 -73.911385
# 1 2018-04-28  10:30        NaN       NaN  40.707070 -73.817190
# 2 2018-04-28  12:47  MANHATTAN   10025.0  40.800186 -73.959145
# 3 2018-04-28  13:15        NaN       NaN  40.798256 -73.827440
# 4 2018-04-28  13:30     QUEENS   11365.0  40.730550 -73.800530
#
#                   LOCATION                    ON.STREET.NAME  \
# 0  (40.680977, -73.911385)  SUMPTER STREET
# 1    (40.70707, -73.81719)  QUEENS BOULEVARD
# 2  (40.800186, -73.959145)                               NaN
# 3   (40.798256, -73.82744)  BRONX WHITESTONE BRIDGE
# 4    (40.73055, -73.80053)  71 AVENUE
#
#   CROSS.STREET.NAME                           OFF.STREET.NAME  \
# 0               NaN                                       NaN
# 1               NaN                                       NaN
# 2               NaN  12        WEST 109 STREET
# 3               NaN                                       NaN
# 4        169 STREET                                       NaN
#
#          ...          SIP_INTERSECTIONS  SAFE_CORRIDORS  PRIORITY_CORRIDORS  \
# 0        ...                          0               0                   1
# 1        ...                          0               0                   1
# 2        ...                          0               0                   0
# 3        ...                          0               0                   0
# 4        ...                          0               0                   0
#
#    PRIORITY_INTERSECTIONS  PRIORITY_ZONES  VZ  YEAR  MONTH DAY_OF_WEEK  \
# 0                       0               1   1  2018      4           5
# 1                       0               1   1  2018      4           5
# 2                       0               0   1  2018      4           5
# 3                       0               0   1  2018      4           5
# 4                       0               0   1  2018      4           5
#
#   NBR_VZ_INITIATIVES
# 0                  2
# 1                  2
# 2                  1
# 3                  0
# 4                  0
#
# [5 rows x 48 columns]

# %%
df3veh_full = df3veh_nvz.append(df3veh_vz)

# %%
df3veh_full.shape
# Out:
# (64620, 48)

# %%
#Write into a csv file
df3veh_full.to_csv('threevehicle-incidents-fulldata-latest.csv', encoding='utf-8', index=False)

# %%
hotspots = prepareHotSpotsForFullData(df3veh_full)
# Out:
# 1556
# Clustered 64,620 points down to 1,556 clusters, for 97.6% compression in 3.21 seconds
# 311
# Clustered 64,620 points down to 311 clusters, for 99.5% compression in 2.99 seconds
# 87
# Clustered 64,620 points down to 87 clusters, for 99.9% compression in 3.49 seconds
# 32
# Clustered 64,620 points down to 32 clusters, for 100.0% compression in 4.38 seconds
# 15
# Clustered 64,620 points down to 15 clusters, for 100.0% compression in 4.50 seconds
# 12
# Clustered 64,620 points down to 12 clusters, for 100.0% compression in 4.79 seconds
# 10
# Clustered 64,620 points down to 10 clusters, for 100.0% compression in 5.18 seconds
# 9
# Clustered 64,620 points down to 9 clusters, for 100.0% compression in 5.95 seconds
# 9
# Clustered 64,620 points down to 9 clusters, for 100.0% compression in 7.03 seconds
# 9
# Clustered 64,620 points down to 9 clusters, for 100.0% compression in 6.55 seconds
# 372
# Clustered 64,620 points down to 372 clusters, for 99.4% compression in 2.60 seconds
# 426
# Clustered 64,620 points down to 426 clusters, for 99.3% compression in 2.90 seconds
# 95
# Clustered 64,620 points down to 95 clusters, for 99.9% compression in 3.45 seconds
# 32
# Clustered 64,620 points down to 32 clusters, for 100.0% compression in 3.84 seconds
# 23
# Clustered 64,620 points down to 23 clusters, for 100.0% compression in 4.02 seconds
# 13
# Clustered 64,620 points down to 13 clusters, for 100.0% compression in 4.46 seconds
# 8
# Clustered 64,620 points down to 8 clusters, for 100.0% compression in 5.26 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 5.15 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 6.22 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 6.80 seconds
# 158
# Clustered 64,620 points down to 158 clusters, for 99.8% compression in 2.47 seconds
# 293
# Clustered 64,620 points down to 293 clusters, for 99.5% compression in 3.14 seconds
# 105
# Clustered 64,620 points down to 105 clusters, for 99.8% compression in 3.55 seconds
# 29
# Clustered 64,620 points down to 29 clusters, for 100.0% compression in 3.36 seconds
# 20
# Clustered 64,620 points down to 20 clusters, for 100.0% compression in 4.21 seconds
# 17
# Clustered 64,620 points down to 17 clusters, for 100.0% compression in 4.73 seconds
# 13
# Clustered 64,620 points down to 13 clusters, for 100.0% compression in 7.72 seconds
# 9
# Clustered 64,620 points down to 9 clusters, for 100.0% compression in 5.67 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 6.04 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 6.25 seconds
# 86
# Clustered 64,620 points down to 86 clusters, for 99.9% compression in 2.35 seconds
# 185
# Clustered 64,620 points down to 185 clusters, for 99.7% compression in 2.58 seconds
# 142
# Clustered 64,620 points down to 142 clusters, for 99.8% compression in 2.75 seconds
# 52
# Clustered 64,620 points down to 52 clusters, for 99.9% compression in 3.22 seconds
# 17
# Clustered 64,620 points down to 17 clusters, for 100.0% compression in 3.53 seconds
# 11
# Clustered 64,620 points down to 11 clusters, for 100.0% compression in 4.43 seconds
# 10
# Clustered 64,620 points down to 10 clusters, for 100.0% compression in 6.59 seconds
# 9
# Clustered 64,620 points down to 9 clusters, for 100.0% compression in 5.35 seconds
# 8
# Clustered 64,620 points down to 8 clusters, for 100.0% compression in 5.53 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 10.00 seconds
# 43
# Clustered 64,620 points down to 43 clusters, for 99.9% compression in 4.28 seconds
# 116
# Clustered 64,620 points down to 116 clusters, for 99.8% compression in 5.61 seconds
# 153
# Clustered 64,620 points down to 153 clusters, for 99.8% compression in 7.30 seconds
# 55
# Clustered 64,620 points down to 55 clusters, for 99.9% compression in 7.10 seconds
# 19
# Clustered 64,620 points down to 19 clusters, for 100.0% compression in 5.46 seconds
# 8
# Clustered 64,620 points down to 8 clusters, for 100.0% compression in 7.60 seconds
# 8
# Clustered 64,620 points down to 8 clusters, for 100.0% compression in 5.46 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 5.35 seconds
# 6
# Clustered 64,620 points down to 6 clusters, for 100.0% compression in 6.28 seconds
# 6
# Clustered 64,620 points down to 6 clusters, for 100.0% compression in 8.83 seconds
# 26
# Clustered 64,620 points down to 26 clusters, for 100.0% compression in 2.74 seconds
# 88
# Clustered 64,620 points down to 88 clusters, for 99.9% compression in 2.75 seconds
# 141
# Clustered 64,620 points down to 141 clusters, for 99.8% compression in 3.12 seconds
# 59
# Clustered 64,620 points down to 59 clusters, for 99.9% compression in 4.11 seconds
# 29
# Clustered 64,620 points down to 29 clusters, for 100.0% compression in 4.55 seconds
# 9
# Clustered 64,620 points down to 9 clusters, for 100.0% compression in 5.57 seconds
# 6
# Clustered 64,620 points down to 6 clusters, for 100.0% compression in 5.32 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 6.19 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 7.97 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 6.62 seconds
# 14
# Clustered 64,620 points down to 14 clusters, for 100.0% compression in 2.24 seconds
# 60
# Clustered 64,620 points down to 60 clusters, for 99.9% compression in 2.78 seconds
# 115
# Clustered 64,620 points down to 115 clusters, for 99.8% compression in 3.00 seconds
# 67
# Clustered 64,620 points down to 67 clusters, for 99.9% compression in 3.50 seconds
# 29
# Clustered 64,620 points down to 29 clusters, for 100.0% compression in 3.98 seconds
# 16
# Clustered 64,620 points down to 16 clusters, for 100.0% compression in 4.77 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 6.53 seconds
# 6
# Clustered 64,620 points down to 6 clusters, for 100.0% compression in 5.92 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 6.19 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 6.59 seconds
# 10
# Clustered 64,620 points down to 10 clusters, for 100.0% compression in 4.13 seconds
# 42
# Clustered 64,620 points down to 42 clusters, for 99.9% compression in 6.47 seconds
# 97
# Clustered 64,620 points down to 97 clusters, for 99.8% compression in 7.22 seconds
# 75
# Clustered 64,620 points down to 75 clusters, for 99.9% compression in 8.99 seconds
# 29
# Clustered 64,620 points down to 29 clusters, for 100.0% compression in 8.63 seconds
# 20
# Clustered 64,620 points down to 20 clusters, for 100.0% compression in 10.41 seconds
# 8
# Clustered 64,620 points down to 8 clusters, for 100.0% compression in 8.42 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 10.59 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 11.40 seconds
# 4
# Clustered 64,620 points down to 4 clusters, for 100.0% compression in 9.55 seconds
# 6
# Clustered 64,620 points down to 6 clusters, for 100.0% compression in 3.43 seconds
# 34
# Clustered 64,620 points down to 34 clusters, for 99.9% compression in 3.85 seconds
# 70
# Clustered 64,620 points down to 70 clusters, for 99.9% compression in 5.18 seconds
# 85
# Clustered 64,620 points down to 85 clusters, for 99.9% compression in 5.09 seconds
# 30
# Clustered 64,620 points down to 30 clusters, for 100.0% compression in 8.22 seconds
# 23
# Clustered 64,620 points down to 23 clusters, for 100.0% compression in 10.83 seconds
# 10
# Clustered 64,620 points down to 10 clusters, for 100.0% compression in 8.36 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 8.54 seconds
# 6
# Clustered 64,620 points down to 6 clusters, for 100.0% compression in 9.32 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 9.96 seconds
# 4
# Clustered 64,620 points down to 4 clusters, for 100.0% compression in 3.45 seconds
# 26
# Clustered 64,620 points down to 26 clusters, for 100.0% compression in 3.84 seconds
# 48
# Clustered 64,620 points down to 48 clusters, for 99.9% compression in 4.06 seconds
# 76
# Clustered 64,620 points down to 76 clusters, for 99.9% compression in 4.52 seconds
# 31
# Clustered 64,620 points down to 31 clusters, for 100.0% compression in 6.04 seconds
# 19
# Clustered 64,620 points down to 19 clusters, for 100.0% compression in 5.79 seconds
# 9
# Clustered 64,620 points down to 9 clusters, for 100.0% compression in 6.41 seconds
# 7
# Clustered 64,620 points down to 7 clusters, for 100.0% compression in 6.81 seconds
# 6
# Clustered 64,620 points down to 6 clusters, for 100.0% compression in 7.60 seconds
# 5
# Clustered 64,620 points down to 5 clusters, for 100.0% compression in 10.15 seconds

# %%
hotspots.shape
# Out:
# (5650, 50)

# %%
hotspots.to_csv('threevehicle-hotspots-fulldata-latest.csv', encoding='utf-8', index=False)
